# %%
import pandas as pd
import sqlite3
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as ss

conn = sqlite3.connect("../db/baltasar.db")
def sql(query):
    return pd.read_sql_query(query, conn)

# %%
sql('SELECT max(blocknumber) FROM Transfer')
# Out:
#    max(blocknumber)
# 0           7680001

# %%
sql('''
SELECT 
    * 
FROM 
    EntityTaxonomy
    NATURAL JOIN
    EntityMetadata
WHERE 
    type = 'mixer' and
    +blocknumber = 7680001 
''')
# Out:
#                                                   name  blocknumber   type  \
# 0           0x0000000000c90bc353314b6911180ed7e06019a9      7680001  mixer
# 1           0x00000f9ec07c056730188b975ead364e253547fa      7680001  mixer
# 2           0x0004e79c978b95974dca16f56b516be0c50cc652      7680001  mixer
# 3           0x0004f896ed610f1d67ded75b3c613df2d3dd13c4      7680001  mixer
# 4           0x0005abcbb9533cf6f9370505ffef25393e0d2852      7680001  mixer
# 5           0x0006e4548aed4502ec8c844567840ce6ef1013f5      7680001  mixer
# 6           0x00071508db163ee69814aad31562f44b787c2d4d      7680001  mixer
# 7     0x00086ebf4774f077125d2bff2124537de94d29d9-couse      7680001  mixer
# 8      0x000bf0664e5c3e321cd62d83fe6ecf14651de125-capp      7680001  mixer
# 9           0x0013effed37dd5e6a5000ee4a0f0f7df505dd010      7680001  mixer
# 10     0x001528c65949338d094aed0ff41de9864714753b-capp      7680001  mixer
# ...
