# %%
import pandas as pd
import sqlite3
import seaborn as sns
import matplotlib.pyplot as plt

conn = sqlite3.connect("../db/baltasar.db")
def sql(query):
    return pd.read_sql_query(query, conn)

# %%
sql('''SELECT token, sum(IFNULL(percentage,0)) as percCapitalization, count(*) 
FROM TokenBalance
WHERE token = "ALL_ADJUSTED"''')
# Out:
#           token  percCapitalization  count(*)
# 0  ALL_ADJUSTED                 1.0  11527755

# %%
sql('SELECT * FROM Token WHERE excludeFromAdjustedVolumes = 1')
# Out:
#                         id  decimals                    name  \
# 0                   revain         0                  Revain
# 1                   utrust        18                  UTRUST
# 2                smartmesh        18               SmartMesh
# 3                noah-coin        18               Noah Coin
# 4                 polybius         6                Polybius
# 5                   0chain        10                  0Chain
# 6                rotharium        18               Rotharium
# 7                 verasity        18                Verasity
# 8                    zmine        18                   ZMINE
# 9                   hacken         8                  Hacken
# 10                skychain         6                Skychain
# 11           next-exchange        18           Next.exchange
# 12          decision-token        18          Decision Token
# 13                    hoqu        18                    HOQU
# ...
